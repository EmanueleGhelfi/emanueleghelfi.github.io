# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
h, w = 9, 9 # Input dimension
H, W = 3, 3 # Output dimension

# %%
x = np.random.uniform(size=(h, w))
plt.imshow(x)
for (j,i),label in np.ndenumerate(x):
    plt.text(i,j,label,ha='center',va='center')
